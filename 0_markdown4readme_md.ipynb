# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/NLP/blob/main/0_markdown4readme_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ✂️✏️📌 **How to Use <font color = 'red'> Markdown Language**
# * ## For <font color = 'orange'> more syntax</font> of markdown langauge, [Click here.](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# # **Keywords**
#
# 1. Font size
# 2. Bold
# 3. Italic
# 4. Font color
# 5. Hyperlink
# 6. Bullet point
# 7. Table
# 8. Shaded cell

# %% [markdown]
# ###<font color = 'pink'>**Exercise**</font>
#
# - shaded cell in gray
# * shaded cells
#     - more examples

# %% [markdown]
# # NLP
#
# # 🐹🍦 **Python Language**
#
# ## **Learning Python** using **Colab** ([Visit Colab homepage](https://colab.research.google.com/?utm_source=scs-index)) and **Github** ([Visit Github homepage](https://github.com/))
#
#
# ### **1. Sign up github** ([Visit a tutorial on Youtube](https://www.youtube.com/watch?v=c-NikCpec7U))
#     You can also sign up using your Google account.
#
# ### **2. Sign up Google Colaboratory** (aka. Colab) ([Visit a tutorial on Youtube](https://www.youtube.com/watch?v=2X_EU18OeYM))
#     You should log in Google (e.g., gmail) so that you can transfer your python file(e.g., .ipynb)
#
#
# ### **3. Useful References**
# - Supplementary textbook for your assignment (for beginners): <font color = 'purple'> _**Exercises 200 파이썬200제**_</font> by 장삼용. 정보문화사 2024
# - Supplementary textbook for general reading <font color = 'red'> _**AI Lecture 2025 인공지능 강연 2025**_</font> by 박태웅. 한빛비즈 2024
# - [Jump to Python](https://wikidocs.net/book/1)
# - [wikidocs for nltk](https://wikidocs.net/21667)
#
# ### **4. Useful pages For Editing text using Markdown Language**
# * [Emoji](https://gist.github.com/rxaviers/7360908)
# * [Markdown syntax](https://www.markdownguide.org/basic-syntax/)
#
#
# ### **5. Class Materials**
# | # | Sessions | Keywords |
# |:--:|:--:|:--:|
# | 0 | Markdown Language 👪  | [syntax](https://github.com/ms624atyale/NLP/blob/main/0_markdown4readme_md.ipynb)|
# | 1 | Code Cells 🐣🐾 | [variable, assign](https://github.com/ms624atyale/NLP/blob/main/1_CodeCells_Basic.ipynb)|
# | 2 | Five Types of Data 📋 | [number, string, list, tuple, dictionary](https://github.com/ms624atyale/NLP/blob/main/2_FiveTypesofData.ipynb)|
# | 3 | Slicing & Indexing ✂️  | [forward indexing, backward indexing, various symbols](https://github.com/ms624atyale/NLP/blob/main/3_indexing.ipynb)|
# | 4 | If statement 😕 | [if, else, colon](https://github.com/ms624atyale/NLP/blob/main/4_1_ifstatement.ipynb)|
# | 5 | Install & Import 🏭  | [package, module, class, function](https://github.com/ms624atyale/NLP/blob/main/5_InstallPackages_ImportModlues_CallFunctions_ChatGPT.ipynb)|
# | 6 | Function 🌿 | [def, colon, indent](https://github.com/ms624atyale/NLP/blob/main/6_DefiningFunctions.ipynb)|
# | 7 | Class 🌴 | [object, instance, instant object, self](https://github.com/ms624atyale/NLP/blob/main/7_Class_simplified.ipynb)|
# | 8 | Read 💻 | [text files, url](https://github.com/ms624atyale/NLP/blob/main/8_ReadTxtFilesImportingfromHTML.ipynb)|
# | 9 | Text Sacraping ✈️ | [text scaping, crawling](https://github.com/ms624atyale/NLP/blob/main/9_TextScrapingwithoutHTMLTags_Saving.ipynb)|
